# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
import matplotlib as mpl
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('./data./apply_train.csv')
df_r = pd.read_csv('./data./resume.csv')
df_rc = pd.read_csv('./data./resume_certificate.csv')
df_re = pd.read_csv('./data./resume_education.csv')
df_rl = pd.read_csv('./data./resume_language.csv')

# %%
df.head()
# Out:
#   resume_seq recruitment_seq
# 0     U05833          R03838
# 1     U06456          R02144
# 2     U07807          R01877
# 3     U04842          R02463
# 4     U08336          R00112

# %%
df_r.head()
# Out:
#   resume_seq    reg_date updated_date  degree  graduate_date  hope_salary  \
# 0     U00606  2020-03-04   2020-05-22       4           2008       3500.0
# 1     U00509  2019-08-25   2020-09-02       2              0          0.0
# 2     U02012  2017-11-20   2020-01-26       5           1979       3500.0
# 3     U04599  2020-05-13   2020-05-28       4           2012          0.0
# 4     U07573  2019-07-23   2020-03-08       4           2010       1900.0
#
#    last_salary                               text_keyword job_code_seq1  \
# 0       3500.0                             스타일디자이너;우븐디자이너   재료·화학·섬유·의복
# 1       3700.0                     상품기획;MD;기획;머천다이저;머천다이징   재료·화학·섬유·의복
# 2       3100.0                                      니트디자인   재료·화학·섬유·의복
# 3       2500.0                                    MD;기획MD   재료·화학·섬유·의복
# 4          0.0  디자이너;남성복;스포츠웨어;편집디자인;코디네이터;일러스트레이터;VMD;MD   재료·화학·섬유·의복
#
#   job_code_seq2 job_code_seq3  career_month    career_job_code
# ...

# %%
df_rc.head()
# Out:
#   resume_seq certificate_contents
# 0     U06421                손해보험사
# 1     U01278              2종운전면허증
# 2     U01008        자동차운전면허 2종 보통
# 3     U03248             운전면허2종보통
# 4     U07483               메이크업3급

# %%
df_re.head()
# Out:
#   resume_seq  hischool_type_seq hischool_special_type hischool_nation  \
# 0     U01419                 21                   일반고              사립
# 1     U03375                 21                   일반고              사립
# 2     U06523                 21                   일반고              사립
# 3     U06619                 21                   일반고              사립
# 4     U05015                 16                  특성화고              공립
#
#   hischool_gender  hischool_location_seq  univ_type_seq1  univ_type_seq2  \
# 0            남자학교                      3               5               5
# 1            여자학교                      3               5               5
# 2            남여공학                      3               5               5
# 3            남여공학                      5               5               5
# 4            남여공학                      3               5               5
#
#    univ_transfer  univ_location univ_major univ_sub_major  univ_major_type  \
# ...

# %%
user_item_matrix = df.groupby(['resume_seq', 'recruitment_seq']).size().unstack(fill_value=0)
user_item_matrix[user_item_matrix>1] = 1

# 사용자 간의 유사성 계산
user_similarity = cosine_similarity(user_item_matrix)

# 추천 점수 계산
user_predicted_scores = user_similarity.dot(user_item_matrix) / np.array([np.abs(user_similarity).sum(axis=1)]).T
